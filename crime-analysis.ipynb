# %%
import pandas as pd
import matplotlib as mplstyle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

college_palette = ["#3498db", "#e74c3c"]
murder_palette = ["#1b9e77", "#d95f02"]

# %%
crime = pd.read_csv('https://raw.githubusercontent.com/cjdd3b/advanced-data-journalism/master/assignments/7-analysis/campus_crime.csv')

# %%
plt.figure(figsize=(200,100))
bar= sns.barplot(x="instname", y="murder", data=crime)

# %%
g  = plt.scatter(\
            x=crime['forcible'], 
            y=crime['agg_aslt'],
            s=crime['total_enr']/1000,
            alpha=0.4)

# %%
g  = plt.scatter(\
            x=crime['forcible'], 
            y=crime['murder'],
            s=crime['total_enr']/1000,
            alpha=0.4)

# %%
crime.describe()
# Out:
#           total_enr      murder  manslaughter    forcible    nonforce  \
# count  2.280000e+02  228.000000    228.000000  228.000000  228.000000
# mean   1.082848e+05    0.021930      0.004386    3.995614    0.048246
# std    1.537517e+05    0.174224      0.066227    5.210543    0.234373
# min    2.016000e+04    0.000000      0.000000    0.000000    0.000000
# 25%    2.949325e+04    0.000000      0.000000    0.000000    0.000000
# 50%    5.477800e+04    0.000000      0.000000    2.000000    0.000000
# 75%    1.227450e+05    0.000000      0.000000    5.250000    0.000000
# max    1.323315e+06    2.000000      1.000000   30.000000    2.000000
#
#           robbery    agg_aslt    burglary     vehicle       arson
# count  228.000000  228.000000  228.000000  228.000000  228.000000
# mean     1.728070    2.583333   23.793860    6.052632    0.820175
# std      2.383072    3.545436   25.235744    8.105409    1.686468
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
gr = sns.lmplot(data=crime, x="murder", y="agg_aslt")

# %%
print ("Story idea: 1.There are four schools who are high outliers in murder. Which ones are they and what are the distinguishable factors that make their rate of murder so much higher?")
# Out:
# Story ideas: 1.There are four schools who are high outliers in murder. Which ones are they and what are the distinguishable factors that make their rate of murder so much higher?

# %%
print ("Story idea: 2. The outlying number of aggravated assaults and number of forcible crimes seem to be perpetrated by smaller schools. Why is this the case? Is there less law enforcement?")
# Out:
# Story ideas: 2. The outlying number of aggravated assaults and number of forcible crimes seem to be perpetrated by smaller schools. Why is this the case? Is there less law enforcement?

# %%
print ("Story idea: 3. There are two schools below the average for aggravated assaults, but high rates of murder. Why are there more murders there if there's not a higher rate of aggravated assault crime?")
# Out:
# Story idea: 3. There are two schools below the average for aggravated assaults, but high rates of murder. Why are there more murders there if there's not a higher rate of aggravated assault crime?
